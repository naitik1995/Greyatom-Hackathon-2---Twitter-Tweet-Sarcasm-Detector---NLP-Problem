# %% [markdown]
# <h1> Import the Data </h1>

# %%
import pandas as pd
import numpy as np

# %%
df_new = pd.read_csv('C:/Users/Naitik/Desktop/sarcasam.csv',dtype=np.str)
df_new.head()
# Out:
#            ID                                              tweet      label
# 0  T000452358                        b'oh yea that makes sense '  sarcastic
# 1  T000452359  Estas enfermedad a un cargo poltico tu como pb...  sarcastic
# 2  T000452360  @alleygirl2409 until i\'m and all the old men ...  sarcastic
# 3  T000452361  b"@sarinas it had been chanted peacefully you ...  sarcastic
# 4  T000452362  b"there's nothing like being on vacation and h...  sarcastic

# %% [markdown]
# <h3> Get info on the data </h3>

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91298 entries, 0 to 91297
# Data columns (total 3 columns):
# ID       91298 non-null object
# tweet    91298 non-null object
# label    91298 non-null object
# dtypes: object(3)
# memory usage: 2.1+ MB

# %%
df_new.isnull().sum()
# Out:
# ID       0
# tweet    0
# label    0
# dtype: int64

# %% [markdown]
# <h3> Get the count of sarcastic and non sarcastic tweets </h3>

# %%
import seaborn as sns

# %%
sns.countplot(df_new['label'])

# %% [markdown]
# <h3> Get the value count of sarcastic and non sarcastic tweets data </h3>

# %%
df_new['label'].values_count()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-478-65a2b70980db> in <module>()
# ----> 1 df_new['label'].values_count()
#
# C:\Users\Naitik\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'values_count'

# %% [markdown]
# <h3> Remove single, double quotes and b' from the text </h3>

# %%
df_new.replace(("b'")," ",regex=True,inplace=True)

# %%
df_new.replace(('b"'),' ',regex=True,inplace=True)

# %%
df_new.replace(("'")," ",regex=True,inplace=True)

# %%
df_new.replace(('"')," ",regex=True,inplace=True)

# %% [markdown]
# <h3> Get the @names values from the tweets</h3>

# %%
m = []
for i in df_new.tweet:
    value_email = re.findall(r'@[a-zA-Z0-9]*', i)
    m.append(value_email)

# %%
m
# Out:
# [[],
#  [],
#  ['@alleygirl2409'],
#  ['@sarinas'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@stoneyj'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@ParijaKavilanz'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@mrsdashiell'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@TXTrendyChick'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@RealLiamPayne'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...

# %% [markdown]
# <h3> Remove @name from the dataset </h3>

# %%
df_new.replace(("@[a-zA-Z0-9]*")," ",regex=True,inplace=True)

# %%
df_new
# Out:
#                ID                                              tweet  \
# 0      T000452358                          oh yea that makes sense
# 1      T000452359  Estas enfermedad a un cargo poltico tu como pb...
# 2      T000452360    until i\ m and all the old men will finally ...
# 3      T000452361     it had been chanted peacefully you can t de...
# 4      T000452362   there s nothing like being on vacation and ha...
# 5      T000452363  People who are sarcastic tend to be better pro...
# 6      T000452364   May I block you too RT But what if he or she ...
# 7      T000452365   Wow I really forgot how much I love the traff...
# 8      T000452366   How perfect my internet just went out thanks ...
# 9      T000452367                      Love having no voice $$SAR$$
# 10     T000452368   Apparently i have to sacrifice a goat and do ...
# 11     T000452369                              Drivers Ed Yay boring
# 12     T000452370   I like how he gets all the credit and not doi...
# ...

# %% [markdown]
# <h3> Remove #sarcasm and #notsarcasm hashtags from the tweets </h3>

# %%
l_sarcasm = []
for i in df_new.tweet:
    value_email = re.findall(r'#sarcasm', i)
    l_sarcasm.append(value_email)

# %%
l_notsarcasm = []
for i in df_new.tweet:
    value_email = re.findall(r'#notsarcasm', i)
    l_notsarcasm.append(value_email)

# %%
df_new.replace(("#sarcasm")," ",regex=True,inplace=True)
df_new.replace(("#notsarcasm")," ",regex=True,inplace=True)

# %%
df_new['Sarcasm'] = l_sarcasm
df_new['NotSarcasm'] = l_notsarcasm

# %% [markdown]
# <h3> Remove Slang from dataset: Eg $$SAR$$ </h3>

# %%
df_new.replace(("[$][a-zA-Z0-9]*")," ",regex=True,inplace=True)

# %%
df_new.replace('/',' ', regex=True,inplace=True)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91298 entries, 0 to 91297
# Data columns (total 5 columns):
# ID            91298 non-null object
# tweet         91298 non-null object
# label         91298 non-null object
# Sarcasm       91298 non-null object
# NotSarcasm    91298 non-null object
# dtypes: object(5)
# memory usage: 3.5+ MB

# %%
df_new.Sarcasm[0] = " ".join(df_new.Sarcasm[0])

# %%
df_new.Sarcasm[2] = " ".join(df_new.Sarcasm[2])

# %%
for i in range(len(df_new.Sarcasm)):
    df_new.Sarcasm[i] = " ".join(df_new.Sarcasm[i])

# %%
for i in range(len(df_new.NotSarcasm)):
    df_new.NotSarcasm[i] = " ".join(df_new.NotSarcasm[i])

# %% [markdown]
# <h3> Remove Special Characters </h3>

# %%
urlpt=df_new["tweet"]
special_char_list = ['\.', '\;', '\?', '\}', '\)', '\{', '\(','/','\-','\#']
for special_char in special_char_list:
    urlpt = urlpt.replace(special_char, ' ',regex=True)
df_new["tweet"]=urlpt

# %% [markdown]
# <h3> Get the capital words </h3>

# %%
cap_words = []
for i in df_new.tweet:
    cap_words.append(len(re.findall('([A-Z]+)', i)))

# %%
df_new['CapitalWordsLength'] = cap_words

# %% [markdown]
# <h3> Find the stopwords and create filtered sentence </h3>

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Naitik\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))

# %%
from nltk import word_tokenize

# %%
tokenized = []
for i in df_new.tweet:
    tokenized.append(word_tokenize(i))

# %%
df_new['Tokenized'] = df_new['tweet'].apply(lambda x:  [w for w in word_tokenize(x) if not w in stop_words])

# %%
df_new['ListLength'] = df_new['Tokenized'].apply(lambda x: len(x))

# %%
df_new
# Out:
#                ID                                              tweet  \
# 0      T000452358                          oh yea that makes sense
# 1      T000452359  Estas enfermedad a un cargo poltico tu como pb...
# 2      T000452360    until i\ m and all the old men will finally ...
# 3      T000452361     it had been chanted peacefully you can t de...
# 4      T000452362   there s nothing like being on vacation and ha...
# 5      T000452363  People who are sarcastic tend to be better pro...
# 6      T000452364   May I block you too RT But what if he or she ...
# 7      T000452365   Wow I really forgot how much I love the traff...
# 8      T000452366   How perfect my internet just went out thanks ...
# 9      T000452367                         Love having no voice
# 10     T000452368   Apparently i have to sacrifice a goat and do ...
# 11     T000452369                              Drivers Ed Yay boring
# 12     T000452370   I like how he gets all the credit and not doi...
# ...

# %%
df_new1 = pd.read_csv('C:/Users/Naitik/Desktop/sarcasam.csv',dtype=np.str)

# %%
df_new['UncleanTweet'] = df_new1['tweet'].copy()

# %%
df_new.drop(columns=['Sarcasm','NotSarcasm'],axis=1,inplace=True)

# %%
df_new.to_csv('./clean_data.csv',encoding='utf-8')

# %%
df_crosscheck = pd.read_csv('./clean_data.csv',encoding='utf-8')

# %%
df_crosscheck.isnull().sum()
# Out:
# Unnamed: 0            0
# ID                    0
# tweet                 0
# label                 0
# CapitalWordsLength    0
# Tokenized             0
# ListLength            0
# UncleanTweet          0
# dtype: int64

# %% [markdown]
# <h3> Filter Non English Language Words </h3>

# %%
from langdetect import detect

# %%
lang = detect(df_new.loc[2][1])

# %%
df_new['Language'] = df_new['UncleanTweet'].apply(lambda x: detect(x))

# %%
df_new['Language'].value_counts()
# Out:
# en    85118
# af      829
# so      601
# es      536
# no      470
# nl      469
# cy      416
# da      377
# fr      341
# tl      309
# ca      221
# it      201
# id      185
# et      169
# sv      168
# de      140
# pt      130
# sl       98
# pl       73
# ro       70
# tr       67
# fi       59
# sk       42
# hr       39
# lv       38
# sw       34
# sq       33
# cs       30
# hu       21
# lt        9
# vi        5
# Name: Language, dtype: int64

# %%
sns.countplot(df_new['Language'])

# %%
df_only_eng = df_new[df_new.Language == 'en']

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85118 entries, 0 to 91297
# Data columns (total 8 columns):
# ID                    85118 non-null object
# tweet                 85118 non-null object
# label                 85118 non-null object
# CapitalWordsLength    85118 non-null int64
# Tokenized             85118 non-null object
# ListLength            85118 non-null int64
# UncleanTweet          85118 non-null object
# Language              85118 non-null object
# dtypes: int64(2), object(6)
# memory usage: 5.8+ MB

# %%
df_only_eng.to_csv('./english_clean_data.csv',encoding='utf-8')

# %% [markdown]
# <h3> Separate Sarcastic and Non Sarcastic </h3>

# %%
df_only_sarcastic = df_new[df_new.label == 'sarcastic']
df_non_sarcastic = df_new[df_new.label == 'non-sarcastic']

# %%
textall = " ".join(df_only_sarcastic['tweet'])
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

wordcloud_sarcastic = WordCloud().generate(textall)

# %%
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud_sarcastic, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
textall = " ".join(df_non_sarcastic['tweet'])
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

wordcloud = WordCloud().generate(textall)

# %%
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wordcloud.words_
# Out:
# {'already': 0.03372175141242938,
#  'alway': 0.07891949152542373,
#  'amazing': 0.0824505649717514,
#  'amp': 0.323975988700565,
#  'another': 0.0480225988700565,
#  'away': 0.03248587570621469,
#  'awesome': 0.0625,
#  'baby': 0.04590395480225989,
#  'back': 0.10328389830508475,
#  'beautiful': 0.08333333333333333,
#  'believe': 0.0323093220338983,
#  'best': 0.10116525423728813,
#  'better': 0.03848870056497175,
#  'big': 0.04678672316384181,
#  'birthday': 0.1682556497175141,
#  'blessed': 0.06338276836158192,
#  'book': 0.04678672316384181,
#  'boy': 0.031603107344632765,
#  'cantwait': 0.03001412429378531,
#  'change': 0.03177966101694915,
#  'check': 0.04007768361581921,
#  'come': 0.08227401129943503,
#  'coming': 0.06161723163841808,
#  'cute': 0.02842514124293785,
#  'dad': 0.04696327683615819,
#  'dance': 0.030543785310734463,
#  'day': 0.3347457627118644,
#  'dog': 0.03866525423728814,
#  'don': 0.04643361581920904,
#  'done': 0.03425141242937853,
# ...

# %%
import operator
sorted_non_sarcastic = sorted(wordcloud.words_.items(), key=operator.itemgetter(1),reverse=True)

# %%
import operator
sorted_sarcastic = sorted(wordcloud_sarcastic.words_.items(), key=operator.itemgetter(1),reverse=True)

# %%
sorted_non_sarcastic
# Out:
# [('rt', 1.0),
#  ('today', 0.350635593220339),
#  ('love', 0.3365112994350282),
#  ('day', 0.3347457627118644),
#  ('amp', 0.323975988700565),
#  ('happy', 0.2930790960451977),
#  ('new', 0.209569209039548),
#  ('will', 0.1986228813559322),
#  ('life', 0.1984463276836158),
#  ('thank', 0.18132062146892655),
#  ('tomorrow', 0.1721398305084746),
#  ('now', 0.16896186440677965),
#  ('birthday', 0.1682556497175141),
#  ('one', 0.1638418079096045),
#  ('father day', 0.16225282485875706),
#  ('make', 0.15995762711864406),
#  ('time', 0.15218926553672316),
#  ('see', 0.14689265536723164),
#  ('thankful', 0.13771186440677965),
#  ('wait', 0.1359463276836158),
#  ('going', 0.1352401129943503),
#  ('first', 0.13241525423728814),
#  ('weekend', 0.13135593220338984),
#  ('week', 0.12694209039548024),
#  ('great', 0.1258827683615819),
#  ('good', 0.12129237288135593),
#  ('got', 0.12129237288135593),
#  ('work', 0.11882062146892655),
#  ('tonight', 0.11687853107344633),
# ...

# %%
#Get words of hashtag and find count of positive or negative word
#wordnet - module for sentiment associated to a word for positive and negative

# %%
#WORDCLOUD for hashtag words sarcasdtic and non sarcastic

# %%
df_new_hashtag = pd.read_csv('C:/Users/Naitik/Desktop/sarcasam.csv',dtype=np.str)

# %%
m_hashtag = []
for i in df_new.UncleanTweet:
    value_email = re.findall (r'#[a-zA-Z0-9]*', i)
    m_hashtag.append(value_email)

# %%
df_new['Hashtags'] = m_hashtag

# %%
df_new
# Out:
#                ID                                              tweet  \
# 0      T000452358                          oh yea that makes sense
# 1      T000452359  Estas enfermedad a un cargo poltico tu como pb...
# 2      T000452360    until i\ m and all the old men will finally ...
# 3      T000452361     it had been chanted peacefully you can t de...
# 4      T000452362   there s nothing like being on vacation and ha...
# 5      T000452363  People who are sarcastic tend to be better pro...
# 6      T000452364   May I block you too RT But what if he or she ...
# 7      T000452365   Wow I really forgot how much I love the traff...
# 8      T000452366   How perfect my internet just went out thanks ...
# 9      T000452367                         Love having no voice
# 10     T000452368   Apparently i have to sacrifice a goat and do ...
# 11     T000452369                              Drivers Ed Yay boring
# 12     T000452370   I like how he gets all the credit and not doi...
# ...

# %%
df_new = df_new[df_new.Language == 'en']

# %%
for i in df_new.Hashtags:
    print(i)
# Out:
# ['#sarcasmsun']
# ['#hypocrisysat']
# []
# []
# []
# []
# []
# []
# ['#ButForReal']
# []
# []
# ['#seriously']
# ['#sarcastic']
# []
# ['#not']
# ['#not']
# []
# []
# []
# ['#not']
# ['#Not']
# []
# []
# []
# []
# []
# []
# []
# []
# ['#not']
# []
# []
# ['#not']
# ['#seriously']
# ['#not']
# ['#sarcasmfri']
# ['#not']
# ['#sarcasm']
# ['#not']
# []
# ['#sarcasm']
# ['#Seriously']
# []
# []
# []
# []
# ['#sarcasm']
# []
# ['#not']
# []
# []
# ['#seriously']
# []
# []
# []
# []
# ['#not', '#justkillme']
# []
# []
# []
# ['#sarcasm']
# []
# []
# []
# []
# []
# []
# []
# ['#not']
# ['#not']
# []
# []
# []
# []
# []
# ['#sarcasmthu']
# []
# []
# []
# []
# []
# []
# ['#not']
# []
# []
# []
# []
# ['#workoutclothessun']
# []
# ['#sarcasm']
# []
# ['#not']
# []
# []
# []
# []
# ['#sarcasm', '#beoriginalfri']
# []
# []
# ['#THGRIS', '#not']
# []
# ['#sarcasm']
# []
# []
# []
# ['#sarcasmwed']
# []
# []
# []
# []
# []
# []
# []
# ['#Sarcasm']
# []
# ['#sarcasm']
# []
# []
# []
# ['#sarcasm']
# ...

# %%
df_hashtags_sarcastic = df_new[df_new.label == 'sarcastic'].Hashtags

# %%
df_hashtags_non_sarcastic = df_new[df_new.label == 'non-sarcastic'].Hashtags

# %%
df_string_sarcastic_hashtag = []
lv_string
for i in df_hashtags_sarcastic:
    for j in i:
        lv_string = "".join(j)
    df_string_sarcastic_hashtag.append(lv_string)
    lv_string = ""

# %%
df_string_non_sarcastic_hashtag = []
lv_string
for i in df_hashtags_non_sarcastic:
    for j in i:
        lv_string = "".join(j)
    df_string_non_sarcastic_hashtag.append(lv_string)
    lv_string = ""

# %%
textall = " ".join(df_string_sarcastic_hashtag)
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

wordcloud_sarcastic_hashtag = WordCloud().generate(textall)

# %%
textall = " ".join(df_string_non_sarcastic_hashtag)
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

wordcloud_non_sarcastic_hashtag = WordCloud().generate(textall)

# %%
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud_sarcastic_hashtag, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud_non_sarcastic_hashtag, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
df_new
# Out:
#                ID                                              tweet  \
# 0      T000452358                          oh yea that makes sense
# 2      T000452360    until i\ m and all the old men will finally ...
# 3      T000452361     it had been chanted peacefully you can t de...
# 4      T000452362   there s nothing like being on vacation and ha...
# 5      T000452363  People who are sarcastic tend to be better pro...
# 6      T000452364   May I block you too RT But what if he or she ...
# 7      T000452365   Wow I really forgot how much I love the traff...
# 8      T000452366   How perfect my internet just went out thanks ...
# 9      T000452367                         Love having no voice
# 10     T000452368   Apparently i have to sacrifice a goat and do ...
# 11     T000452369                              Drivers Ed Yay boring
# 12     T000452370   I like how he gets all the credit and not doi...
# 13     T000452371                    Ohhhh no   Seriously  seriously
# ...

# %%
import nltk
nltk.download('sentiwordnet')
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\Naitik\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\sentiwordnet.zip.
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Naitik\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
from nltk.corpus import sentiwordnet as swn

# %%
lv_string = 'I m so good at focusing while doing homework'
from nltk import word_tokenize
tokens = word_tokenize(lv_string)

# %%
print(tokens)
# Out:
# ['I', 'm', 'so', 'good', 'at', 'focusing', 'while', 'doing', 'homework']

# %%
pos_score = []
neg_score = []
tagged = nltk.pos_tag(tokens)
pos=0
neg=0
obj=0
count=0
count_pos = 0
count_neg = 0
for word, tag in tagged:
    ss_set = None
    ss_set = list(swn.senti_synsets(word))
    if len(ss_set) != 0:
        pos=pos+ss_set[0].pos_score()
        neg=neg+ss_set[0].neg_score()
        obj=obj+ss_set[0].obj_score()
        if pos > neg:
            count_pos += 1
        if neg > pos:
            count_neg += 1
    pos = 0
    neg = 0
    obj = 0
pos_score.append(count_pos)
neg_score.append(count_neg)
# Out:
# Word I and Positive Score 0.0
# Word I and Negative Score 0.0
# Final Score 0.0
# Word m and Positive Score 0.0
# Word m and Negative Score 0.0
# Final Score 0.0
# Word so and Positive Score 0.0
# Word so and Negative Score 0.0
# Final Score 0.0
# Word good and Positive Score 0.5
# Word good and Negative Score 0.0
# Final Score 0.5
# Word at and Positive Score 0.5
# Word at and Negative Score 0.0
# Final Score 0.5
# Word focusing and Positive Score 0.625
# Word focusing and Negative Score 0.0
# Final Score 0.625
# Word while and Positive Score 0.625
# Word while and Negative Score 0.0
# Final Score 0.625
# Word doing and Positive Score 0.625
# Word doing and Negative Score 0.0
# Final Score 0.625
# Word homework and Positive Score 0.625
# Word homework and Negative Score 0.0
# Final Score 0.625

# %%
print(tagged)
# Out:
# [('People', 'NNS'), ('who', 'WP'), ('are', 'VBP'), ('sarcastic', 'JJ'), ('tend', 'NN'), ('to', 'TO'), ('be', 'VB'), ('better', 'JJR'), ('problem', 'NN'), ('solvers', 'NNS'), ('I', 'PRP'), ('can', 'MD'), ('solve', 'VB'), ('anything', 'NN')]

# %%
senti_score = []
pos_score = []
neg_score = []
for i in df_new.Tokenized:
    tagged = nltk.pos_tag(i)
    pos=0
    neg=0
    obj=0
    count=0
    count_pos = 0
    count_neg = 0
    for word, tag in tagged:
        ss_set = None
        ss_set = list(swn.senti_synsets(word))
        if len(ss_set) != 0:
            pos=ss_set[0].pos_score()
            neg=ss_set[0].neg_score()
            if np.abs(pos) > np.abs(neg):
                count_pos += 1
            if np.abs(neg) > np.abs(pos):
                count_neg += 1
        pos = 0
        neg = 0
        obj = 0
    pos_score.append(count_pos)
    neg_score.append(count_neg)

# %%
df_new['Positive Score'] = pos_score
# Out:
# C:\Users\Naitik\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new['Negative Score'] = neg_score
# Out:
# C:\Users\Naitik\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new
# Out:
#                ID                                              tweet  \
# 0      T000452358                          oh yea that makes sense
# 2      T000452360    until i\ m and all the old men will finally ...
# 3      T000452361     it had been chanted peacefully you can t de...
# 4      T000452362   there s nothing like being on vacation and ha...
# 5      T000452363  People who are sarcastic tend to be better pro...
# 6      T000452364   May I block you too RT But what if he or she ...
# 7      T000452365   Wow I really forgot how much I love the traff...
# 8      T000452366   How perfect my internet just went out thanks ...
# 9      T000452367                         Love having no voice
# 10     T000452368   Apparently i have to sacrifice a goat and do ...
# 11     T000452369                              Drivers Ed Yay boring
# 12     T000452370   I like how he gets all the credit and not doi...
# 13     T000452371                    Ohhhh no   Seriously  seriously
# ...

# %%
df_new.drop(columns=['Language'],inplace=True)
# Out:
# C:\Users\Naitik\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85118 entries, 0 to 91297
# Data columns (total 10 columns):
# ID                    85118 non-null object
# tweet                 85118 non-null object
# label                 85118 non-null object
# CapitalWordsLength    85118 non-null int64
# Tokenized             85118 non-null object
# ListLength            85118 non-null int64
# UncleanTweet          85118 non-null object
# Hashtags              85118 non-null object
# Positive Score        85118 non-null int64
# Negative Score        85118 non-null int64
# dtypes: int64(4), object(6)
# memory usage: 9.6+ MB

# %%
df_new.drop(columns=['Hashtags'],inplace=True)
# Out:
# C:\Users\Naitik\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85118 entries, 0 to 91297
# Data columns (total 9 columns):
# ID                    85118 non-null object
# tweet                 85118 non-null object
# label                 85118 non-null object
# CapitalWordsLength    85118 non-null int64
# Tokenized             85118 non-null object
# ListLength            85118 non-null int64
# UncleanTweet          85118 non-null object
# Positive Score        85118 non-null int64
# Negative Score        85118 non-null int64
# dtypes: int64(4), object(5)
# memory usage: 9.0+ MB

# %%
df_new.to_csv('./final_data.csv')

# %%
wordcloud_sarcastic_hashtag.words_
# Out:
# {'BlueJays': 0.0010196278358399185,
#  'CharlestonShooting': 0.0030588835075197555,
#  'ConfederateFlag': 0.0007647208768799389,
#  'Day': 0.0007647208768799389,
#  'DonaldTrump': 0.0010196278358399185,
#  'EliminationChamber': 0.0007647208768799389,
#  'Fact': 0.0010196278358399185,
#  'HappyMonday': 0.0007647208768799389,
#  'NASCAR': 0.002039255671679837,
#  'NBAAllStar': 0.0017843487127198571,
#  'NBAFinals': 0.0007647208768799389,
#  'NFL': 0.0007647208768799389,
#  'NFLCombine': 0.0007647208768799389,
#  'NHL': 0.0007647208768799389,
#  'Oscars': 0.012235534030079022,
#  'RAW': 0.0030588835075197555,
#  'RedSox': 0.0017843487127198571,
#  'TheBachelor': 0.0015294417537598777,
#  'TheBachelorette': 0.0015294417537598777,
#  'TheWalkingDead': 0.002039255671679837,
#  'USOpen': 0.002803976548559776,
#  'WWE': 0.0017843487127198571,
#  'WWEChamber': 0.002039255671679837,
#  'WalkingDead': 0.0007647208768799389,
#  'afc': 0.0007647208768799389,
#  'alcohol': 0.0007647208768799389,
# ...

# %%
sorted_non_sarcastic = sorted(wordcloud_non_sarcastic_hashtag.words_.items(), key=operator.itemgetter(1),reverse=True)

# %%
sorted_non_sarcastic
# Out:
# [('thankful', 1.0),
#  ('love', 0.9287020109689214),
#  ('healthy', 0.6928702010968921),
#  ('affirmation', 0.6215722120658135),
#  ('fathersday', 0.6069469835466179),
#  ('model', 0.4405850091407678),
#  ('blessed', 0.42778793418647165),
#  ('smile', 0.42047531992687387),
#  ('life', 0.35283363802559414),
#  ('happy', 0.3473491773308958),
#  ('birthday', 0.3436928702010969),
#  ('day', 0.33089579524680074),
#  ('happiness', 0.2742230347349177),
#  ('cantwait', 0.26691042047531993),
#  ('nervous', 0.263254113345521),
#  ('weekend', 0.24862888482632542),
#  ('family', 0.2449725776965265),
#  ('friday', 0.22851919561243145),
#  ('summer', 0.226691042047532),
#  ('grateful', 0.21572212065813529),
#  ('proud', 0.21572212065813529),
#  ('quote', 0.17184643510054845),
#  ('fun', 0.16453382084095064),
#  ('friend', 0.15539305301645337),
#  ('music', 0.14442413162705667),
#  ('father', 0.14076782449725778),
#  ('inspirational', 0.13528336380255943),
#  ('bouncingbaby', 0.1316270566727605),
# ...
